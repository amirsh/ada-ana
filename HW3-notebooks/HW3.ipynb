# %%
import pandas as pd
import numpy as np
pd.options.mode.chained_assignment = None  # default='warn'

# %%
test_data = pd.read_csv("data/P3_GrantExport.csv", sep=';')
test_data
# Out:
#        ﻿"Project Number"                                      Project Title  \
# 0                      1  Schlussband (Bd. VI) der Jacob Burckhardt-Biog...
# 1                      4  Batterie de tests à l'usage des enseignants po...
# 2                      5  Kritische Erstausgabe der "Evidentiae contra D...
# 3                      6  Katalog der datierten Handschriften in der Sch...
# 4                      7  Wissenschaftliche Mitarbeit am Thesaurus Lingu...
# 5                      8  Die schweizerische Wirtschaftspolitik seit dem...
# 6                      9  Theologische Forschungen zur Oekumene (Studien...
# 7                     10  Konfuzianische Kulturwerte in der sozialen Ent...
# 8                     11  Edizione degli scritti di Aurelio de' Giorgi B...
# 9                     13  La construction de nouveautés au sein des morp...
# 10                    14  Wissensstruktur, Fragegenese und Wissenserweit...
# ...

# %%
ts = test_data.dropna()["University"]
ts.value_counts()
# Out:
# Universität Zürich - ZH                               2302
# ETH Zürich - ETHZ                                     2182
# Université de Genève - GE                             1930
# EPF Lausanne - EPFL                                   1802
# Universität Bern - BE                                 1694
# Universität Basel - BS                                1472
# Université de Lausanne - LA                           1369
# Université de Fribourg - FR                            720
# Université de Neuchâtel - NE                           448
# Paul Scherrer Institut - PSI                           281
# Università della Svizzera italiana - USI               198
# Zürcher Fachhochschule (ohne PH) - ZFH                 187
# NPO (Biblioth., Museen, Verwalt.) - NPO                168
# Eidg. Material und Prüfungsanstalt - EMPA              166
# HES de Suisse occidentale - HES-SO                     158
# Fachhochschule Nordwestschweiz (ohne PH) - FHNW        149
# ...

# %%
d2 = pd.read_csv("data/P3_PersonExport.csv", sep=';')
d2
# Out:
#           ﻿"Last Name"    First Name  Gender  \
# 0              a Marca        Andrea    male
# 1              a Marca        Davide    male
# 2               Aaberg         Johan    male
# 3               Aahman       Josefin  female
# 4                Aalai       Mandana  female
# 5             Äämismaa         Päivi    male
# 6                Aapro      Matti S.    male
# 7              Aardoom       Raphael    male
# 8                  Aas        Gregor    male
# 9              Aassila      Mohammed    male
# 10                 Aav         Riina  female
# 11              Abadie         Brice    male
# 12             Abadier       Michael    male
# 13         Abad-Villar     Eva Maria  female
# 14            Abakumov         Artem    male
# 15             Aballea        Sylvie  female
# 16          Abalmassov      Veniamin    male
# 17              Abanin        Dmitry    male
# 18             Abankwa        Daniel    male
# 19             Abardia         Judit  female
# ...
